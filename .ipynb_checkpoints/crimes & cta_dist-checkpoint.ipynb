# %%
import pandas as pd
import numpy as np
import censusdata
import geopandas as gpd
import geoplot as gplt
from matplotlib.patches import Polygon
from shapely.ops import nearest_points
import requests
import json

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Crimes

# %% [markdown]
# Things to do:
# - Incorporate N/S/E/W (see Eric's example)
# - Neighborhoods
# - Clean out outliers - the crimes per capita is off!
# - Convert things to API

# %%
# API: https://data.cityofchicago.org/resource/ijzp-q8t2.json
# source: https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2/data
# crimes = pd.read_csv("../data/chicago-crimes-2019.csv")
crimes = pd.read_csv("data/Crimes-2013-2019.csv")
crimes
# Out:
#                ID Case Number                    Date                  Block  \
# 0        11994465    JD167343  08/26/2013 12:01:00 AM   062XX S ST LOUIS AVE
# 1         9137935    HW283197  05/18/2013 04:00:00 AM     034XX N CICERO AVE
# 2        12053700    JD236020  03/26/2013 12:01:00 AM  014XX N CLAREMONT AVE
# 3         9439554    HW583930  12/25/2013 10:24:00 PM  073XX S GREENWOOD AVE
# 4        11863840    JC475022  10/16/2013 08:13:00 PM        017XX W 21ST ST
# ...           ...         ...                     ...                    ...
# 1912149     24550    JC270190  05/20/2019 01:13:00 AM  001XX N HERMITAGE AVE
# 1912150     24551    JC271105  05/20/2019 06:07:00 PM       078XX S STATE ST
# 1912151     24554    JC274572  05/23/2019 01:00:00 AM  069XX S MAPLEWOOD AVE
# 1912152     24556    JC276141  05/24/2019 02:12:00 AM        013XX W 61ST ST
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
#
#          IUCR                Primary Type  \
# 0        0265     CRIMINAL SEXUAL ASSAULT
# 1        0281     CRIMINAL SEXUAL ASSAULT
# 2        0266     CRIMINAL SEXUAL ASSAULT
# 3        0326                     ROBBERY
# 4        1752  OFFENSE INVOLVING CHILDREN
# ...       ...                         ...
# 1912149  0110                    HOMICIDE
# 1912150  0110                    HOMICIDE
# 1912151  0110                    HOMICIDE
# 1912152  0110                    HOMICIDE
# 1912153  0110                    HOMICIDE
#
#                                                Description  \
# 0                                       AGGRAVATED - OTHER
# 1                                           NON-AGGRAVATED
# 2                                                PREDATORY
# 3                           AGGRAVATED VEHICULAR HIJACKING
# 4        AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# ...                                                    ...
# 1912149                                FIRST DEGREE MURDER
# 1912150                                FIRST DEGREE MURDER
# 1912151                                FIRST DEGREE MURDER
# 1912152                                FIRST DEGREE MURDER
# 1912153                                FIRST DEGREE MURDER
#
#             Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                      RESIDENCE   False      True  ...  23.0            66.0
# 1                      RESIDENCE   False     False  ...  31.0            15.0
# 2        MEDICAL / DENTAL OFFICE   False     False  ...   1.0            24.0
# 3                         STREET    True     False  ...   5.0            69.0
# 4                      RESIDENCE   False     False  ...  25.0            31.0
# ...                          ...     ...       ...  ...   ...             ...
# 1912149                   STREET   False     False  ...  27.0            28.0
# 1912150                   STREET   False     False  ...   6.0            69.0
# 1912151                    PORCH   False     False  ...  17.0            66.0
# 1912152                   GARAGE   False     False  ...  16.0            67.0
# 1912153                   STREET   False     False  ...  17.0            69.0
#
#          FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0              02           NaN          NaN  2013  05/22/2020 03:46:29 PM
# 1              02           NaN          NaN  2013  05/21/2020 03:47:16 PM
# 2              02           NaN          NaN  2013  05/19/2020 03:51:22 PM
# 3              03     1184825.0    1856507.0  2013  05/18/2020 03:45:11 PM
# 4              17           NaN          NaN  2013  05/16/2020 03:46:46 PM
# ...           ...           ...          ...   ...                     ...
# 1912149       01A     1164708.0    1901279.0  2019  05/27/2019 04:12:56 PM
# 1912150       01A     1177650.0    1852817.0  2019  05/27/2019 04:12:56 PM
# 1912151       01A     1160573.0    1858532.0  2019  05/30/2019 04:12:42 PM
# 1912152       01A     1168477.0    1864312.0  2019  05/31/2019 04:09:56 PM
# 1912153       01A     1174853.0    1853877.0  2019  06/01/2019 04:04:59 PM
#
#           Latitude  Longitude                       Location
# 0              NaN        NaN                            NaN
# 1              NaN        NaN                            NaN
# 2              NaN        NaN                            NaN
# 3        41.761413 -87.598159     (41.7614134, -87.59815938)
# 4              NaN        NaN                            NaN
# ...            ...        ...                            ...
# 1912149  41.884721 -87.670624  (41.884720804, -87.670624155)
# 1912150  41.751453 -87.624568  (41.751452878, -87.624567581)
# 1912151  41.767505 -87.686989  (41.767504682, -87.686989416)
# 1912152  41.783199 -87.657851  (41.783199083, -87.657851361)
# 1912153  41.754424 -87.634786  (41.754424418, -87.634785654)
#
# [1912154 rows x 22 columns]

# %% [markdown]
# ### Overview of data sources:
# - ACS: American Community Survey: total population by block
# - Census: provides census block boundaries (multi-polygon)
# - Crime: crime with location (lat/long)

# %%
crime_gdf = gpd.GeoDataFrame(
    crimes, geometry=gpd.points_from_xy(crimes.Longitude, crimes.Latitude))

census_gdf = gpd.read_file("https://data.cityofchicago.org/resource/bt9m-d2mf.geojson?$limit=9999999")

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018]
tables = ['B02001_001E']

def gather_census(years, tables):
    df = pd.DataFrame()
    for t in tables:
        table = pd.DataFrame()
        for y in years:
            temp = pd.DataFrame(censusdata.download(
                 "acs5", y, censusdata.censusgeo(
                 [("state", "17"), ("county", "031"), ("block group", "*")]),
                 [t, "GEO_ID"])).reset_index(drop=True)
            temp['Year'] = y
            table = table.append(temp)
            
        if df.shape[0] == 0:
            df = table
        else:
            df = pd.merge(df, table, how="inner", on=["GEO_ID", "Year"])
            
    return df

# %%
acs_df = gather_census(years, tables)
acs_df = acs_df.rename(columns={"B02001_001E": "total_pop"})
acs_df
# Out:
#       total_pop                 GEO_ID  Year
# 0          1064  1500000US170310302003  2013
# 1          1828  1500000US170310302004  2013
# 2          1306  1500000US170310303001  2013
# 3          1625  1500000US170310303002  2013
# 4          1450  1500000US170310304001  2013
# ...         ...                    ...   ...
# 3988       1393  1500000US170312909004  2018
# 3989        926  1500000US170318288014  2018
# 3990        679  1500000US170315103003  2018
# 3991       1591  1500000US170316304002  2018
# 3992       1829  1500000US170311603001  2018
#
# [23958 rows x 3 columns]

# %%
census_gdf["geo_12"] = census_gdf["geoid10"].map(lambda x: str(x)[:12])
acs_df["geo_12"] = acs_df["GEO_ID"].map(lambda x: str(x)[-12:])

# %%
census_gdf
# Out:
#       statefp10      name10 blockce10  tract_bloc          geoid10 tractce10  \
# 0            17  Block 2010      2010  6903002010  170316903002010    690300
# 1            17  Block 3007      3007  6809003007  170316809003007    680900
# 2            17  Block 3013      3013  6809003013  170316809003013    680900
# 3            17  Block 4019      4019  2909004019  170312909004019    290900
# 4            17  Block 4016      4016  2925004016  170312925004016    292500
# ...         ...         ...       ...         ...              ...       ...
# 46352        17  Block 1028      1028  2203001028  170312203001028    220300
# 46353        17  Block 1030      1030  2203001030  170312203001030    220300
# 46354        17  Block 2014      2014  8310002014  170318310002014    831000
# 46355        17  Block 2001      2001  8310002001  170318310002001    831000
# 46356        17  Block 1007      1007  2214001007  170312214001007    221400
#
#       countyfp10                                           geometry  \
# 0            031  MULTIPOLYGON (((-87.62907 41.76909, -87.62905 ...
# 1            031  MULTIPOLYGON (((-87.63412 41.77447, -87.63410 ...
# 2            031  MULTIPOLYGON (((-87.63485 41.77263, -87.63522 ...
# 3            031  MULTIPOLYGON (((-87.73841 41.85913, -87.73842 ...
# 4            031  MULTIPOLYGON (((-87.73217 41.85476, -87.73226 ...
# ...          ...                                                ...
# 46352        031  MULTIPOLYGON (((-87.69323 41.92767, -87.69385 ...
# 46353        031  MULTIPOLYGON (((-87.69320 41.92667, -87.69351 ...
# 46354        031  MULTIPOLYGON (((-87.67759 41.91624, -87.67759 ...
# 46355        031  MULTIPOLYGON (((-87.67398 41.91783, -87.67397 ...
# 46356        031  MULTIPOLYGON (((-87.69683 41.92340, -87.69683 ...
#
#              geo_12
# 0      170316903002
# 1      170316809003
# 2      170316809003
# 3      170312909004
# 4      170312925004
# ...             ...
# 46352  170312203001
# 46353  170312203001
# 46354  170318310002
# 46355  170318310002
# 46356  170312214001
#
# [46357 rows x 9 columns]

# %%
#merged census block geometries and total population per block
merged_gdf = acs_df.merge(census_gdf, on="geo_12", how="inner")
merged_gdf = gpd.GeoDataFrame(merged_gdf)
merged_gdf
# Out:
#         total_pop                 GEO_ID  Year        geo_12 statefp10  \
# 0            1064  1500000US170310302003  2013  170310302003        17
# 1            1064  1500000US170310302003  2013  170310302003        17
# 2            1064  1500000US170310302003  2013  170310302003        17
# 3            1064  1500000US170310302003  2013  170310302003        17
# 4            1064  1500000US170310302003  2013  170310302003        17
# ...           ...                    ...   ...           ...       ...
# 278137          0  1500000US170319801001  2018  170319801001        17
# 278138          0  1500000US170319801001  2018  170319801001        17
# 278139          0  1500000US170319801001  2018  170319801001        17
# 278140          0  1500000US170319801001  2018  170319801001        17
# 278141          0  1500000US170319801001  2018  170319801001        17
#
#             name10 blockce10  tract_bloc          geoid10 tractce10  \
# 0       Block 3010      3010  0302003010  170310302003010    030200
# 1       Block 3004      3004  0302003004  170310302003004    030200
# 2       Block 3012      3012  0302003012  170310302003012    030200
# 3       Block 3000      3000  0302003000  170310302003000    030200
# 4       Block 3014      3014  0302003014  170310302003014    030200
# ...            ...       ...         ...              ...       ...
# 278137  Block 1002      1002  9801001002  170319801001002    980100
# 278138  Block 1008      1008  9801001008  170319801001008    980100
# 278139  Block 1005      1005  9801001005  170319801001005    980100
# 278140  Block 1004      1004  9801001004  170319801001004    980100
# 278141  Block 1001      1001  9801001001  170319801001001    980100
#
#        countyfp10                                           geometry
# 0             031  MULTIPOLYGON (((-87.66764 41.99218, -87.66764 ...
# 1             031  MULTIPOLYGON (((-87.66525 41.99357, -87.66525 ...
# 2             031  MULTIPOLYGON (((-87.66520 41.99176, -87.66519 ...
# 3             031  MULTIPOLYGON (((-87.66528 41.99450, -87.66528 ...
# 4             031  MULTIPOLYGON (((-87.66940 41.99081, -87.66954 ...
# ...           ...                                                ...
# 278137        031  MULTIPOLYGON (((-87.73894 41.79108, -87.73893 ...
# 278138        031  MULTIPOLYGON (((-87.74174 41.78770, -87.74165 ...
# 278139        031  MULTIPOLYGON (((-87.75442 41.77819, -87.75516 ...
# 278140        031  MULTIPOLYGON (((-87.74162 41.79304, -87.74162 ...
# 278141        031  MULTIPOLYGON (((-87.73891 41.78952, -87.73884 ...
#
# [278142 rows x 12 columns]

# %%
#merged the acs-census data with crime data
allmerged_gdf = gpd.sjoin(crime_gdf, merged_gdf, how='left')
allmerged_gdf
# Out:
# /Users/ezhang/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
#                ID Case Number                    Date                  Block  \
# 0        11994465    JD167343  08/26/2013 12:01:00 AM   062XX S ST LOUIS AVE
# 1         9137935    HW283197  05/18/2013 04:00:00 AM     034XX N CICERO AVE
# 2        12053700    JD236020  03/26/2013 12:01:00 AM  014XX N CLAREMONT AVE
# 3         9439554    HW583930  12/25/2013 10:24:00 PM  073XX S GREENWOOD AVE
# 3         9439554    HW583930  12/25/2013 10:24:00 PM  073XX S GREENWOOD AVE
# ...           ...         ...                     ...                    ...
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
# 1912153     24558    JC278685  05/25/2019 11:43:00 PM        004XX W 77TH ST
#
#          IUCR             Primary Type                     Description  \
# 0        0265  CRIMINAL SEXUAL ASSAULT              AGGRAVATED - OTHER
# 1        0281  CRIMINAL SEXUAL ASSAULT                  NON-AGGRAVATED
# 2        0266  CRIMINAL SEXUAL ASSAULT                       PREDATORY
# 3        0326                  ROBBERY  AGGRAVATED VEHICULAR HIJACKING
# 3        0326                  ROBBERY  AGGRAVATED VEHICULAR HIJACKING
# ...       ...                      ...                             ...
# 1912153  0110                 HOMICIDE             FIRST DEGREE MURDER
# 1912153  0110                 HOMICIDE             FIRST DEGREE MURDER
# 1912153  0110                 HOMICIDE             FIRST DEGREE MURDER
# 1912153  0110                 HOMICIDE             FIRST DEGREE MURDER
# 1912153  0110                 HOMICIDE             FIRST DEGREE MURDER
#
#             Location Description  Arrest  Domestic  ...  \
# 0                      RESIDENCE   False      True  ...
# 1                      RESIDENCE   False     False  ...
# 2        MEDICAL / DENTAL OFFICE   False     False  ...
# 3                         STREET    True     False  ...
# 3                         STREET    True     False  ...
# ...                          ...     ...       ...  ...
# 1912153                   STREET   False     False  ...
# 1912153                   STREET   False     False  ...
# 1912153                   STREET   False     False  ...
# 1912153                   STREET   False     False  ...
# 1912153                   STREET   False     False  ...
#
#                         GEO_ID  Year_right        geo_12  statefp10  \
# 0                          NaN         NaN           NaN        NaN
# 1                          NaN         NaN           NaN        NaN
# 2                          NaN         NaN           NaN        NaN
# 3        1500000US170318418001      2013.0  170318418001         17
# 3        1500000US170318418001      2014.0  170318418001         17
# ...                        ...         ...           ...        ...
# 1912153  1500000US170316912001      2014.0  170316912001         17
# 1912153  1500000US170316912001      2015.0  170316912001         17
# 1912153  1500000US170316912001      2016.0  170316912001         17
# 1912153  1500000US170316912001      2017.0  170316912001         17
# 1912153  1500000US170316912001      2018.0  170316912001         17
#
#              name10  blockce10  tract_bloc          geoid10 tractce10  \
# 0               NaN        NaN         NaN              NaN       NaN
# 1               NaN        NaN         NaN              NaN       NaN
# 2               NaN        NaN         NaN              NaN       NaN
# 3        Block 1003       1003  8418001003  170318418001003    841800
# 3        Block 1003       1003  8418001003  170318418001003    841800
# ...             ...        ...         ...              ...       ...
# 1912153  Block 1016       1016  6912001016  170316912001016    691200
# 1912153  Block 1016       1016  6912001016  170316912001016    691200
# 1912153  Block 1016       1016  6912001016  170316912001016    691200
# 1912153  Block 1016       1016  6912001016  170316912001016    691200
# 1912153  Block 1016       1016  6912001016  170316912001016    691200
#
#          countyfp10
# 0               NaN
# 1               NaN
# 2               NaN
# 3               031
# 3               031
# ...             ...
# 1912153         031
# 1912153         031
# 1912153         031
# 1912153         031
# 1912153         031
#
# [11346965 rows x 35 columns]

# %%
#keeping only necessary columns
limited_gdf = allmerged_gdf[["total_pop", "ID", "Case Number", "Year_left", "Primary Type", "blockce10", "GEO_ID", "geometry"]]
limited_gdf
# Out:
#          total_pop        ID Case Number  Year_left             Primary Type  \
# 0              NaN  11994465    JD167343       2013  CRIMINAL SEXUAL ASSAULT
# 1              NaN   9137935    HW283197       2013  CRIMINAL SEXUAL ASSAULT
# 2              NaN  12053700    JD236020       2013  CRIMINAL SEXUAL ASSAULT
# 3            481.0   9439554    HW583930       2013                  ROBBERY
# 3            609.0   9439554    HW583930       2013                  ROBBERY
# ...            ...       ...         ...        ...                      ...
# 1912153     1275.0     24558    JC278685       2019                 HOMICIDE
# 1912153     1342.0     24558    JC278685       2019                 HOMICIDE
# 1912153     1701.0     24558    JC278685       2019                 HOMICIDE
# 1912153     1461.0     24558    JC278685       2019                 HOMICIDE
# 1912153     1734.0     24558    JC278685       2019                 HOMICIDE
#
#         blockce10                 GEO_ID                geometry
# 0             NaN                    NaN         POINT (nan nan)
# 1             NaN                    NaN         POINT (nan nan)
# 2             NaN                    NaN         POINT (nan nan)
# 3            1003  1500000US170318418001  POINT (-87.598 41.761)
# 3            1003  1500000US170318418001  POINT (-87.598 41.761)
# ...           ...                    ...                     ...
# 1912153      1016  1500000US170316912001  POINT (-87.635 41.754)
# 1912153      1016  1500000US170316912001  POINT (-87.635 41.754)
# 1912153      1016  1500000US170316912001  POINT (-87.635 41.754)
# 1912153      1016  1500000US170316912001  POINT (-87.635 41.754)
# 1912153      1016  1500000US170316912001  POINT (-87.635 41.754)
#
# [11346965 rows x 8 columns]

# %%
limited_gdf = limited_gdf[limited_gdf.total_pop != 0]
limited_gdf = limited_gdf.dropna()
limited_gdf = limited_gdf.drop_duplicates('Case Number')
limited_gdf
# Out:
#          total_pop       ID Case Number  Year_left  \
# 3            481.0  9439554    HW583930       2013
# 5           1292.0  9394321    HW537926       2013
# 8           1180.0  9244995    HW387664       2013
# 10          1043.0  9113866    HW258115       2013
# 14          1119.0  9162922    HW307727       2013
# ...            ...      ...         ...        ...
# 1912149     1136.0    24550    JC270190       2019
# 1912150     1580.0    24551    JC271105       2019
# 1912151     1364.0    24554    JC274572       2019
# 1912152      923.0    24556    JC276141       2019
# 1912153     1372.0    24558    JC278685       2019
#
#                        Primary Type blockce10                 GEO_ID  \
# 3                           ROBBERY      1003  1500000US170318418001
# 5        OFFENSE INVOLVING CHILDREN      1006  1500000US170312518001
# 8                       SEX OFFENSE      3007  1500000US170316604003
# 10                      SEX OFFENSE      2002  1500000US170315102002
# 14                          BATTERY      1024  1500000US170316718001
# ...                             ...       ...                    ...
# 1912149                    HOMICIDE      1028  1500000US170312804001
# 1912150                    HOMICIDE      2012  1500000US170316913002
# 1912151                    HOMICIDE      2009  1500000US170316609002
# 1912152                    HOMICIDE      2012  1500000US170316709002
# 1912153                    HOMICIDE      1016  1500000US170316912001
#
#                            geometry
# 3        POINT (-87.59816 41.76141)
# 5        POINT (-87.75337 41.88171)
# 8        POINT (-87.70937 41.78070)
# 10       POINT (-87.56344 41.71644)
# 14       POINT (-87.65573 41.76048)
# ...                             ...
# 1912149  POINT (-87.67062 41.88472)
# 1912150  POINT (-87.62457 41.75145)
# 1912151  POINT (-87.68699 41.76750)
# 1912152  POINT (-87.65785 41.78320)
# 1912153  POINT (-87.63479 41.75442)
#
# [1873950 rows x 8 columns]

# %% [markdown]
# ### Calculating crime per capita for each block

# %%
count_by_block = pd.Series(limited_gdf.groupby(['GEO_ID', 'Year_left'])['Case Number'].count(), name='crime_count').reset_index()
count_by_block = count_by_block.rename(columns={"Year_left": "Year"})
count_by_block
# Out:
#                       GEO_ID  Year  crime_count
# 0      1500000US170310101001  2013           81
# 1      1500000US170310101001  2014           76
# 2      1500000US170310101001  2015           91
# 3      1500000US170310101001  2016           61
# 4      1500000US170310101001  2017           79
# ...                      ...   ...          ...
# 15229  1500000US170318439005  2015           61
# 15230  1500000US170318439005  2016           64
# 15231  1500000US170318439005  2017           50
# 15232  1500000US170318439005  2018           95
# 15233  1500000US170318439005  2019          107
#
# [15234 rows x 3 columns]

# %%
sum(count_by_block['crime_count'])
# Out:
# 1873950

# %%
crimes_and_pop = count_by_block.merge(acs_df, on=["GEO_ID","Year"], how="inner").reset_index()
crimes_and_pop
# Out:
#        index                 GEO_ID  Year  crime_count  total_pop  \
# 0          0  1500000US170310101001  2013           81        526
# 1          1  1500000US170310101001  2014           76        421
# 2          2  1500000US170310101001  2015           91        435
# 3          3  1500000US170310101001  2016           61        639
# 4          4  1500000US170310101001  2017           79        594
# ...      ...                    ...   ...          ...        ...
# 13052  13052  1500000US170318439005  2014           78        652
# 13053  13053  1500000US170318439005  2015           61        699
# 13054  13054  1500000US170318439005  2016           64        832
# 13055  13055  1500000US170318439005  2017           50        754
# 13056  13056  1500000US170318439005  2018           95        963
#
#              geo_12
# 0      170310101001
# 1      170310101001
# 2      170310101001
# 3      170310101001
# 4      170310101001
# ...             ...
# 13052  170318439005
# 13053  170318439005
# 13054  170318439005
# 13055  170318439005
# 13056  170318439005
#
# [13057 rows x 6 columns]

# %%
joined2=crimes_and_pop
joined2
# Out:
#        index                 GEO_ID  Year  crime_count  total_pop  \
# 0          0  1500000US170310101001  2013           81        526
# 1          1  1500000US170310101001  2014           76        421
# 2          2  1500000US170310101001  2015           91        435
# 3          3  1500000US170310101001  2016           61        639
# 4          4  1500000US170310101001  2017           79        594
# ...      ...                    ...   ...          ...        ...
# 13052  13052  1500000US170318439005  2014           78        652
# 13053  13053  1500000US170318439005  2015           61        699
# 13054  13054  1500000US170318439005  2016           64        832
# 13055  13055  1500000US170318439005  2017           50        754
# 13056  13056  1500000US170318439005  2018           95        963
#
#              geo_12
# 0      170310101001
# 1      170310101001
# 2      170310101001
# 3      170310101001
# 4      170310101001
# ...             ...
# 13052  170318439005
# 13053  170318439005
# 13054  170318439005
# 13055  170318439005
# 13056  170318439005
#
# [13057 rows x 6 columns]

# %% [markdown]
# ### Cleaning up data

# %%
# removing rows where population is 0
joined2 = joined2[joined2.total_pop != 0]
joined2.dropna()
joined2.reset_index()
joined2
# Out:
#        index                 GEO_ID  Year  crime_count  total_pop  \
# 0          0  1500000US170310101001  2013           81        526
# 1          1  1500000US170310101001  2014           76        421
# 2          2  1500000US170310101001  2015           91        435
# 3          3  1500000US170310101001  2016           61        639
# 4          4  1500000US170310101001  2017           79        594
# ...      ...                    ...   ...          ...        ...
# 13052  13052  1500000US170318439005  2014           78        652
# 13053  13053  1500000US170318439005  2015           61        699
# 13054  13054  1500000US170318439005  2016           64        832
# 13055  13055  1500000US170318439005  2017           50        754
# 13056  13056  1500000US170318439005  2018           95        963
#
#              geo_12
# 0      170310101001
# 1      170310101001
# 2      170310101001
# 3      170310101001
# 4      170310101001
# ...             ...
# 13052  170318439005
# 13053  170318439005
# 13054  170318439005
# 13055  170318439005
# 13056  170318439005
#
# [13056 rows x 6 columns]

# %%
joined2['crimes_per_capita'] = joined2['crime_count']/joined2['total_pop']
# Out:
# /Users/ezhang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
joined2

# %%
final_gdf = gpd.GeoDataFrame(joined2)
final_gdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d0c9b87e1cc7> in <module>
# ----> 1 final_gdf = gpd.GeoDataFrame(joined2)
#       2 final_gdf
#
# NameError: name 'gpd' is not defined

# %%
final_gdf['crimes_per_capita'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b8931b133683> in <module>
# ----> 1 final_gdf['crimes_per_capita'].describe()
#
# NameError: name 'final_gdf' is not defined

# %% [markdown]
# ### Graphing crimes

# %%
# ALREADY CALCULATED CRIMES PER CAPITA EARLIER
# crime_graph = final_gdf.groupby('GEO_ID').sum().reset_index()
# crime_graph = crime_graph[['GEO_ID', 'crime_count', 'total_pop']]
# crime_graph['crimes_per_capita'] = crime_graph['crime_count']/crime_graph['total_pop']
# crime_graph
# Out:
#                      GEO_ID  crime_count  total_pop  crimes_per_capita
# 0     1500000US170310101001          437       3106           0.140695
# 1     1500000US170310101002         1928      11612           0.166035
# 2     1500000US170310101003         1049      11999           0.087424
# 3     1500000US170310102011          476       9548           0.049853
# 4     1500000US170310102012         1815      27280           0.066532
# ...                     ...          ...        ...                ...
# 2174  1500000US170318439001         1934       5039           0.383806
# 2175  1500000US170318439002          662       2465           0.268560
# 2176  1500000US170318439003          130       5322           0.024427
# 2177  1500000US170318439004          399       3999           0.099775
# 2178  1500000US170318439005          455       4385           0.103763
#
# [2179 rows x 4 columns]

# %%
merged_gdf[['GEO_ID', 'geometry']]
# Out:
#                        GEO_ID  \
# 0       1500000US170310302003
# 1       1500000US170310302003
# 2       1500000US170310302003
# 3       1500000US170310302003
# 4       1500000US170310302003
# ...                       ...
# 278137  1500000US170319801001
# 278138  1500000US170319801001
# 278139  1500000US170319801001
# 278140  1500000US170319801001
# 278141  1500000US170319801001
#
#                                                  geometry
# 0       MULTIPOLYGON (((-87.66764 41.99218, -87.66764 ...
# 1       MULTIPOLYGON (((-87.66525 41.99357, -87.66525 ...
# 2       MULTIPOLYGON (((-87.66520 41.99176, -87.66519 ...
# 3       MULTIPOLYGON (((-87.66528 41.99450, -87.66528 ...
# 4       MULTIPOLYGON (((-87.66940 41.99081, -87.66954 ...
# ...                                                   ...
# 278137  MULTIPOLYGON (((-87.73894 41.79108, -87.73893 ...
# 278138  MULTIPOLYGON (((-87.74174 41.78770, -87.74165 ...
# 278139  MULTIPOLYGON (((-87.75442 41.77819, -87.75516 ...
# 278140  MULTIPOLYGON (((-87.74162 41.79304, -87.74162 ...
# 278141  MULTIPOLYGON (((-87.73891 41.78952, -87.73884 ...
#
# [278142 rows x 2 columns]

# %%
crime_graph2 = crime_graph.merge(merged_gdf[['GEO_ID', 'geometry']], on='GEO_ID')
crime_graph2 = gpd.GeoDataFrame(crime_graph2)
crime_graph2['log_crime_rate'] = np.log(crime_graph2['crimes_per_capita'])
crime_graph2 = crime_graph2.drop_duplicates('geometry')
crime_graph2
# Out:
#                        GEO_ID  crime_count  total_pop  crimes_per_capita  \
# 0       1500000US170310101001          437       3106           0.140695
# 1       1500000US170310101001          437       3106           0.140695
# 2       1500000US170310101001          437       3106           0.140695
# 3       1500000US170310101001          437       3106           0.140695
# 24      1500000US170310101002         1928      11612           0.166035
# ...                       ...          ...        ...                ...
# 277296  1500000US170318439005          455       4385           0.103763
# 277297  1500000US170318439005          455       4385           0.103763
# 277298  1500000US170318439005          455       4385           0.103763
# 277299  1500000US170318439005          455       4385           0.103763
# 277300  1500000US170318439005          455       4385           0.103763
#
#                                                  geometry  log_crime_rate
# 0       MULTIPOLYGON (((-87.66635 42.02252, -87.66666 ...       -1.961158
# 1       MULTIPOLYGON (((-87.67009 42.02115, -87.67047 ...       -1.961158
# 2       MULTIPOLYGON (((-87.67009 42.02226, -87.66994 ...       -1.961158
# 3       MULTIPOLYGON (((-87.66754 42.02224, -87.66763 ...       -1.961158
# 24      MULTIPOLYGON (((-87.67231 42.02285, -87.67231 ...       -1.795556
# ...                                                   ...             ...
# 277296  MULTIPOLYGON (((-87.57160 41.77319, -87.57162 ...       -2.265647
# 277297  MULTIPOLYGON (((-87.56997 41.77307, -87.56997 ...       -2.265647
# 277298  MULTIPOLYGON (((-87.56993 41.77170, -87.56994 ...       -2.265647
# 277299  MULTIPOLYGON (((-87.57156 41.77168, -87.57157 ...       -2.265647
# 277300  MULTIPOLYGON (((-87.56833 41.77302, -87.56830 ...       -2.265647
#
# [46182 rows x 6 columns]

# %%
crime_graph2.plot(figsize=(20, 20), column='log_crime_rate', cmap=plt.cm.coolwarm, legend=True)

# %% [markdown]
# # Transit

# %%
from shapely.ops import nearest_points
from shapely.geometry import Point
import geopy.distance

# %%
cta_df = pd.read_csv("data/CTA-LStops.csv")
cta_df.head()
# the two gdfs are: cta_gdf and census_gdf
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
def clean(df):
    split = df.split(',')
    lst = []
    for i in split:
         lst.append(i.strip('() '))
    return lst

cta_df['location_split'] = cta_df['Location'].apply(lambda x: clean(x))
cta_df['Longitude'] = cta_df['location_split'].map(lambda x: float(x[1]))
cta_df['Latitude'] = cta_df['location_split'].map(lambda x: float(x[0]))

cta_df.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location           location_split  Longitude   Latitude
# 0  (41.857908, -87.669147)  [41.857908, -87.669147] -87.669147  41.857908
# 1  (41.857908, -87.669147)  [41.857908, -87.669147] -87.669147  41.857908
# 2  (41.829353, -87.680622)  [41.829353, -87.680622] -87.680622  41.829353
# 3  (41.829353, -87.680622)  [41.829353, -87.680622] -87.680622  41.829353
# 4  (41.831677, -87.625826)  [41.831677, -87.625826] -87.625826  41.831677

# %%
cta_gdf = gpd.GeoDataFrame(
    cta_df, geometry=gpd.points_from_xy(cta_df.Longitude, cta_df.Latitude))
cta_gdf = cta_gdf[['STOP_ID', 'STOP_NAME', 'STATION_NAME', 'Longitude', 'Latitude', 'geometry']]
cta_gdf
# Out:
#      STOP_ID                           STOP_NAME          STATION_NAME  \
# 0      30162            18th (54th/Cermak-bound)                  18th
# 1      30161                   18th (Loop-bound)                  18th
# 2      30022            35th/Archer (Loop-bound)           35th/Archer
# 3      30023          35th/Archer (Midway-bound)           35th/Archer
# 4      30214     35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
# ..       ...                                 ...                   ...
# 295    30106                 Wilson (95th-bound)                Wilson
# 296    30383      Washington/Wabash (Outer Loop)     Washington/Wabash
# 297    30385                 Wilson (Loop-bound)                Wilson
# 298    30033  Ashland (Harlem-54th/Cermak-bound)               Ashland
# 299    30032           Ashland (Loop-63rd-bound)               Ashland
#
#      Longitude   Latitude                    geometry
# 0   -87.669147  41.857908  POINT (-87.66915 41.85791)
# 1   -87.669147  41.857908  POINT (-87.66915 41.85791)
# 2   -87.680622  41.829353  POINT (-87.68062 41.82935)
# 3   -87.680622  41.829353  POINT (-87.68062 41.82935)
# 4   -87.625826  41.831677  POINT (-87.62583 41.83168)
# ..         ...        ...                         ...
# 295 -87.657588  41.964273  POINT (-87.65759 41.96427)
# 296 -87.626189  41.883220  POINT (-87.62619 41.88322)
# 297 -87.657588  41.964273  POINT (-87.65759 41.96427)
# 298 -87.666969  41.885269  POINT (-87.66697 41.88527)
# 299 -87.666969  41.885269  POINT (-87.66697 41.88527)
#
# [300 rows x 6 columns]

# %%
#census_gdf2 = allmerged_gdf2.sample(10)
#census_gdf2
census_gdf2 = allmerged_gdf.dropna()
census_gdf2 = census_gdf2.drop_duplicates('GEO_ID')
census_gdf2.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year_left', 'Updated On', 'Latitude', 'Longitude',
#        'Location', 'geometry', 'index_right', 'total_pop', 'GEO_ID',
#        'Year_right', 'geo_12', 'statefp10', 'name10', 'blockce10',
#        'tract_bloc', 'geoid10', 'tractce10', 'countyfp10'],
#       dtype='object')

# %%
census_gdf2 = census_gdf2[['GEO_ID', 'Latitude', 'Longitude', 'geometry']]
census_gdf2
# Out:
#                        GEO_ID   Latitude  Longitude  \
# 3       1500000US170318418001  41.761413 -87.598159
# 5       1500000US170312518001  41.881713 -87.753368
# 8       1500000US170316604003  41.780705 -87.709365
# 10      1500000US170315102002  41.716443 -87.563440
# 14      1500000US170316718001  41.760483 -87.655729
# ...                       ...        ...        ...
# 107048  1500000US170317707002  41.980739 -87.878798
# 148481  1500000US170318233041  41.691678 -87.691670
# 542275  1500000US170317708002  41.957636 -87.884013
# 773918  1500000US170318081002  42.001454 -87.806750
# 920511  1500000US170318079003  41.997354 -87.753143
#
#                           geometry
# 3       POINT (-87.59816 41.76141)
# 5       POINT (-87.75337 41.88171)
# 8       POINT (-87.70937 41.78070)
# 10      POINT (-87.56344 41.71644)
# 14      POINT (-87.65573 41.76048)
# ...                            ...
# 107048  POINT (-87.87880 41.98074)
# 148481  POINT (-87.69167 41.69168)
# 542275  POINT (-87.88401 41.95764)
# 773918  POINT (-87.80675 42.00145)
# 920511  POINT (-87.75314 41.99735)
#
# [2187 rows x 4 columns]

# %%
# source: https://gis.stackexchange.com/questions/222315/geopandas-find-nearest-point-in-other-dataframe
# nearest point in gpd2 (cta_gdf) for each row in gpd1 (census_gdf)

# unary union of CTA 
pts3 = cta_gdf.geometry.unary_union
def near(point, pts=pts3):
    # find the nearest point and return the corresponding Place value
    nearest = cta_gdf.geometry == nearest_points(point, pts)[1]
    return max(cta_gdf[nearest].STOP_ID)
  
    
census_gdf2['STOP_ID'] = census_gdf2.apply(lambda row: near(row.geometry), axis=1)
census_gdf2
# Out:
#                        GEO_ID   Latitude  Longitude  \
# 3       1500000US170318418001  41.761413 -87.598159
# 5       1500000US170312518001  41.881713 -87.753368
# 8       1500000US170316604003  41.780705 -87.709365
# 10      1500000US170315102002  41.716443 -87.563440
# 14      1500000US170316718001  41.760483 -87.655729
# ...                       ...        ...        ...
# 107048  1500000US170317707002  41.980739 -87.878798
# 148481  1500000US170318233041  41.691678 -87.691670
# 542275  1500000US170317708002  41.957636 -87.884013
# 773918  1500000US170318081002  42.001454 -87.806750
# 920511  1500000US170318079003  41.997354 -87.753143
#
#                           geometry  STOP_ID
# 3       POINT (-87.59816 41.76141)    30140
# 5       POINT (-87.75337 41.88171)    30136
# 8       POINT (-87.70937 41.78070)    30220
# 10      POINT (-87.56344 41.71644)    30089
# 14      POINT (-87.65573 41.76048)    30057
# ...                            ...      ...
# 107048  POINT (-87.87880 41.98074)    30160
# 148481  POINT (-87.69167 41.69168)    30089
# 542275  POINT (-87.88401 41.95764)    30172
# 773918  POINT (-87.80675 42.00145)    30146
# 920511  POINT (-87.75314 41.99735)    30248
#
# [2187 rows x 5 columns]

# %%
merged_with_cta = census_gdf2.merge(cta_gdf, on="STOP_ID", how="left")
merged_with_cta
# Out:
#                      GEO_ID  Latitude_x  Longitude_x  \
# 0     1500000US170318418001   41.761413   -87.598159
# 1     1500000US170312518001   41.881713   -87.753368
# 2     1500000US170316604003   41.780705   -87.709365
# 3     1500000US170315102002   41.716443   -87.563440
# 4     1500000US170316718001   41.760483   -87.655729
# ...                     ...         ...          ...
# 2182  1500000US170317707002   41.980739   -87.878798
# 2183  1500000US170318233041   41.691678   -87.691670
# 2184  1500000US170317708002   41.957636   -87.884013
# 2185  1500000US170318081002   42.001454   -87.806750
# 2186  1500000US170318079003   41.997354   -87.753143
#
#                       geometry_x  STOP_ID  \
# 0     POINT (-87.59816 41.76141)    30140
# 1     POINT (-87.75337 41.88171)    30136
# 2     POINT (-87.70937 41.78070)    30220
# 3     POINT (-87.56344 41.71644)    30089
# 4     POINT (-87.65573 41.76048)    30057
# ...                          ...      ...
# 2182  POINT (-87.87880 41.98074)    30160
# 2183  POINT (-87.69167 41.69168)    30089
# 2184  POINT (-87.88401 41.95764)    30172
# 2185  POINT (-87.80675 42.00145)    30146
# 2186  POINT (-87.75314 41.99735)    30248
#
#                                      STOP_NAME    STATION_NAME  Longitude_y  \
# 0                 Cottage Grove (Harlem-bound)   Cottage Grove   -87.605857
# 1                       Laramie (Harlem-bound)         Laramie   -87.754986
# 2                        Kedzie (Midway-bound)          Kedzie   -87.704406
# 3                   95th/Dan Ryan (95th-bound)   95th/Dan Ryan   -87.624342
# 4              Ashland/63rd (Terminal arrival)    Ashland/63rd   -87.663766
# ...                                        ...             ...          ...
# 2182                Rosemont (Forest Pk-bound)        Rosemont   -87.859388
# 2183                95th/Dan Ryan (95th-bound)   95th/Dan Ryan   -87.624342
# 2184                  O'Hare (Forest Pk-bound)          O'Hare   -87.904223
# 2185  Harlem (O'Hare Branch) (Forest Pk-bound)          Harlem   -87.808900
# 2186          Jefferson Park (Forest Pk-bound)  Jefferson Park   -87.760892
#
#       Latitude_y                  geometry_y
# 0      41.780309  POINT (-87.60586 41.78031)
# 1      41.887163  POINT (-87.75499 41.88716)
# 2      41.804236  POINT (-87.70441 41.80424)
# 3      41.722377  POINT (-87.62434 41.72238)
# 4      41.778860  POINT (-87.66377 41.77886)
# ...          ...                         ...
# 2182   41.983507  POINT (-87.85939 41.98351)
# 2183   41.722377  POINT (-87.62434 41.72238)
# 2184   41.977665  POINT (-87.90422 41.97767)
# 2185   41.982270  POINT (-87.80890 41.98227)
# 2186   41.970634  POINT (-87.76089 41.97063)
#
# [2187 rows x 10 columns]

# %%
def calc_distance(coords_1, coords_2):
    return geopy.distance.distance(coords_1, coords_2).miles

merged_with_cta['distance'] = merged_with_cta.apply(lambda row: calc_distance((row.Longitude_x, row.Latitude_x), (row.Longitude_y, row.Latitude_y)), axis=1)
merged_with_cta
# Out:
#                      GEO_ID  Latitude_x  Longitude_x  \
# 0     1500000US170318418001   41.761413   -87.598159
# 1     1500000US170312518001   41.881713   -87.753368
# 2     1500000US170316604003   41.780705   -87.709365
# 3     1500000US170315102002   41.716443   -87.563440
# 4     1500000US170316718001   41.760483   -87.655729
# ...                     ...         ...          ...
# 2182  1500000US170317707002   41.980739   -87.878798
# 2183  1500000US170318233041   41.691678   -87.691670
# 2184  1500000US170317708002   41.957636   -87.884013
# 2185  1500000US170318081002   42.001454   -87.806750
# 2186  1500000US170318079003   41.997354   -87.753143
#
#                       geometry_x  STOP_ID  \
# 0     POINT (-87.59816 41.76141)    30140
# 1     POINT (-87.75337 41.88171)    30136
# 2     POINT (-87.70937 41.78070)    30220
# 3     POINT (-87.56344 41.71644)    30089
# 4     POINT (-87.65573 41.76048)    30057
# ...                          ...      ...
# 2182  POINT (-87.87880 41.98074)    30160
# 2183  POINT (-87.69167 41.69168)    30089
# 2184  POINT (-87.88401 41.95764)    30172
# 2185  POINT (-87.80675 42.00145)    30146
# 2186  POINT (-87.75314 41.99735)    30248
#
#                                      STOP_NAME    STATION_NAME  Longitude_y  \
# 0                 Cottage Grove (Harlem-bound)   Cottage Grove   -87.605857
# 1                       Laramie (Harlem-bound)         Laramie   -87.754986
# 2                        Kedzie (Midway-bound)          Kedzie   -87.704406
# 3                   95th/Dan Ryan (95th-bound)   95th/Dan Ryan   -87.624342
# 4              Ashland/63rd (Terminal arrival)    Ashland/63rd   -87.663766
# ...                                        ...             ...          ...
# 2182                Rosemont (Forest Pk-bound)        Rosemont   -87.859388
# 2183                95th/Dan Ryan (95th-bound)   95th/Dan Ryan   -87.624342
# 2184                  O'Hare (Forest Pk-bound)          O'Hare   -87.904223
# 2185  Harlem (O'Hare Branch) (Forest Pk-bound)          Harlem   -87.808900
# 2186          Jefferson Park (Forest Pk-bound)  Jefferson Park   -87.760892
#
#       Latitude_y                  geometry_y  distance
# 0      41.780309  POINT (-87.60586 41.78031)  0.537042
# 1      41.887163  POINT (-87.75499 41.88716)  0.113297
# 2      41.804236  POINT (-87.70441 41.80424)  0.350314
# 3      41.722377  POINT (-87.62434 41.72238)  4.226759
# 4      41.778860  POINT (-87.66377 41.77886)  0.560197
# ...          ...                         ...       ...
# 2182   41.983507  POINT (-87.85939 41.98351)  1.347092
# 2183   41.722377  POINT (-87.62434 41.72238)  4.673552
# 2184   41.977665  POINT (-87.90422 41.97767)  1.403533
# 2185   41.982270  POINT (-87.80890 41.98227)  0.157663
# 2186   41.970634  POINT (-87.76089 41.97063)  0.542687
#
# [2187 rows x 11 columns]

# %%
merged_with_cta = gpd.GeoDataFrame(merged_with_cta)
merged_with_cta = merged_with_cta.rename(columns={"geometry_x": "geometry"})

# %%
merged_with_cta.plot(figsize=(20, 20), column='distance', cmap=plt.cm.coolwarm, legend=True)

# %% [markdown]
# ## Saving datasets to csv

# %%
# from crimes: final_gdf ... from CTA: merged_with_cta
final_crimes = final_gdf
final_gdf.to_csv('crimes.csv')

# %%
final_cta = merged_with_cta[['GEO_ID','STOP_ID','STATION_NAME', 'distance']]
final_cta.to_csv('cta_dist.csv')
